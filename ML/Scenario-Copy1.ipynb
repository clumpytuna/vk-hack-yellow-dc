# %%
import dialogue

# %%
from deeppavlov import configs
from deeppavlov.core.commands.infer import build_model

odqa = build_model(configs.odqa.ru_odqa_infer_wiki, load_trained=True, download=True)
# Out:
# 2019-09-29 02:43:39.899 INFO in 'deeppavlov.core.data.utils'['utils'] at line 64: Downloading from http://files.deeppavlov.ai/deeppavlov_data/squad_model_ru_1.4_cpu_compatible.tar.gz to /home/captain/.deeppavlov/squad_model_ru_1.4_cpu_compatible.tar.gz
# 100%|██████████| 533M/533M [00:41<00:00, 12.9MB/s]
# 2019-09-29 02:44:21.202 INFO in 'deeppavlov.core.data.utils'['utils'] at line 216: Extracting /home/captain/.deeppavlov/squad_model_ru_1.4_cpu_compatible.tar.gz archive into /home/captain/.deeppavlov/models
# 2019-09-29 02:44:25.753 INFO in 'deeppavlov.core.data.utils'['utils'] at line 64: Downloading from http://files.deeppavlov.ai/datasets/wikipedia/ruwiki.tar.gz to /home/captain/.deeppavlov/ruwiki.tar.gz
# 100%|██████████| 1.52G/1.52G [02:01<00:00, 12.5MB/s]
# 2019-09-29 02:46:26.868 INFO in 'deeppavlov.core.data.utils'['utils'] at line 216: Extracting /home/captain/.deeppavlov/ruwiki.tar.gz archive into /home/captain/.deeppavlov/downloads
# ...

# %%
odqa(['Сколько картин написал Ван Гог?'])
# Out:
# ['более ста пятидесяти']

# %%
from deeppavlov import build_model, configs

# %%
model = build_model(configs.squad.squad_ru_bert, download=False)
# Out:
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb51c1bd4a8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb51c1bd4a8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb51c1bd4a8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb51c1bd4a8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# ...

# %%
model(['Девочка на шаре это потрясающая картина созданная в начале 20го века'], ['Когда создана девочка на шаре?'])
# Out:
# [['в начале 20го века'], [50], [73621008.0]]

# %%
# !wget https://pushkinmuseum.art/json/objects.json
# Out:
# --2019-09-28 16:08:46--  https://pushkinmuseum.art/json/objects.json
# Resolving pushkinmuseum.art (pushkinmuseum.art)... 185.87.198.138, 2a03:c980:b957:c68a:185:87:198:138
# Connecting to pushkinmuseum.art (pushkinmuseum.art)|185.87.198.138|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10722788 (10M) [application/json]
# Saving to: ‘objects.json’
#
# objects.json        100%[===================>]  10.23M  12.1MB/s    in 0.8s
#
# 2019-09-28 16:08:47 (12.1 MB/s) - ‘objects.json’ saved [10722788/10722788]

# %%
import pandas as pd
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)

# %%
json = pd.read_json('objects.json', orient='index')

# %%
json['name'][:5]
# Out:
# 3666    {'ru': 'Палетка в форме страуса', 'en': 'Ostri...
# 3664    {'ru': 'Палетка в форме слона', 'en': 'Elephan...
# 3665    {'ru': 'Палетка в форме рыбы', 'en': 'Fish-sha...
# 3730    {'ru': 'Палетка с головами двух птиц', 'en': '...
# 3731    {'ru': 'Палетка в виде черепахи', 'en': 'Turtl...
# Name: name, dtype: object

# %%
for s in json['graphics_type']:
    try:
        print(int(s))
    except:
        print(s)
# Out:
# {'ru': 'Печатная графика', 'en': 'Печатная графика'}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {'ru': 'Печатная графика', 'en': 'Печатная графика'}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {'ru': 'Оригинальная графика', 'en': 'Оригинальная графика'}
# ...

# %%
json[:5]
# Out:
#                 annotation            audioguide authors  building  cast  \
# 3666  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}             116.0     0
# 3664  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}             116.0     0
# 3665  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}             116.0     0
# 3730  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}             116.0     0
# 3731  {'ru': '', 'en': ''}  {'ru': '', 'en': ''}             116.0     0
#
#                                              collectors  \
# 3666  {'1': {'auth_year': '0', 'ru': 'Голенищев Влад...
# 3664  {'1': {'auth_year': '0', 'ru': 'Голенищев Влад...
# 3665  {'1': {'auth_year': '0', 'ru': 'Голенищев Влад...
# 3730
# 3731
#
#                               country department  \
# 3666  {'ru': 'Египет', 'en': 'Egypt'}         79
# 3664  {'ru': 'Египет', 'en': 'Egypt'}         79
# 3665  {'ru': 'Египет', 'en': 'Egypt'}         79
# 3730  {'ru': 'Египет', 'en': 'Egypt'}         79
# ...

# %%
json.columns
# Out:
# Index(['annotation', 'audioguide', 'authors', 'building', 'cast', 'collectors',
#        'country', 'department', 'from', 'gallery', 'get_year', 'graphics_type',
#        'hall', 'inv_num', 'link', 'linktext', 'litra', 'm_parent_id', 'makers',
#        'masterpiece', 'material', 'matvos', 'name', 'namecom', 'origplace',
#        'paint_school', 'path', 'period', 'prodcast', 'producein', 'restor',
#        'seakeys', 'searcha', 'shop', 'show_in_collection', 'show_in_hall',
#        'size', 'sizevos', 'sortID', 'text', 'type', 'videoguide', 'year'],
#       dtype='object')

# %%
import os
import pymorphy2
import re
import chardet
from nltk.tokenize import WordPunctTokenizer

def lemmatize(text):
    text = " ".join(word.lower() for word in text.split()) #lowercasing and removing short words 
    text = re.sub('\-\s\r\n\s{1,}|\-\s\r\n|\r\n', '', text) #deleting newlines and line-breaks
    text = re.sub('[.,:;%©?*,!@#$%^&()\d]|[+=]|[[]|[]]|[/]|"|\s{2,}|-', ' ', text) #deleting symbols  
    text = " ".join(pymorphy2.MorphAnalyzer().parse(word)[0].normal_form for word in text.split())
    return text

# %%
navigation_words = 'где находится туалет кафе камера хранения пройти карта столовая куда пойти идем зал найти путь'
navigatoin_phrases = ['в каком зале', 'где висит', 'где стоит', 'где найти', 'где выставляется', 'где посмотреть', 'как пройти', 'какой маршрут']

# %%
def make_find_set(words, phrases):
    lemmed_words = lemmatize(words.lower()).split()
    phrases = [phrase.lower() for phrase in phrases]
    find_set = set(lemmed_words + phrases)
    return find_set

# %%
import numpy as np

# %%
navigation_find_set = make_find_set(navigation_words, navigatoin_phrases)

# %%
classify('Где находится Левитан?', [navigation_find_set])
# Out:
# 0

# %%
def classify(text, find_sets):
    lemmed = lemmatize(text.lower())
    finded = np.zeros(len(find_sets))
    for i, find_set in enumerate(find_sets):
        for item in find_set:
            if item in lemmed:
                finded[i] += 1
    result_class = np.argmax(finded)
    return result_class

# %%
class BaseScenario:
    def __init__(self):
        pass
    
    def answer(self, state):
        pass

# %%
class Dialogue:
    def __init__(self, find_sets, models):
        self.scenarios = []
        self.find_sets = find_sets
        self.models = models
        self.state = {}
        self.state['history_user'] = []
        self.state['history_bot'] = []
        self.state['return_to_id'] = -1
    
    def answer(self, text):
        self.state['history_user'].append(text)
        if self.state['return_to_id'] != -1:
            current_class = self.state['return_to_id']
        else:
            current_class = classify(text, self.find_sets)
        return self.scenarios[current_class].answer(self.state, self.models)

# %%
def apply_lemm(lst):
    return [lemmatize(word) for word in lst]


class NavigationScenario(BaseScenario):
    # SCENARIO_ID=0
    def __init__(self):
        pass
    
    def answer(state, models):
        text = state['history_user'][-1]
        
        # RETURNS
        if state['return_to_id'] == 0:
            state['return_to_id'] = -1
            if state['return_message'] == 'where':
                text = state['history_user'][-2] # Старый текст, куда хочет юзер
                tokens, ners = models['ner_model']([text])
                tokens = np.array(tokens[0])
                ners = np.array(ners[0])
                mask = ners != 'O'
                lemmatize_text = lemmatize(text.lower())
                text_lemm_set = set(lemmatize_text.split())
                for i, cl in enumerate(ners):
                if 'ORG' in cl:
                    mask[i] = False
                search_queue = ['', [''], ' '.join(tokens[mask])]
                search_result = models['search'].find(search_queue) #TODO SPECIFY
                
                new_text = state['history_user'][-1] # Откуда идет юзер
                zal_number = int(''.join(list(filter(str.isdigit, new_text.lower()))))
                
                
                
                
        tokens, ners = models['ner_model']([text])
        tokens = np.array(tokens[0])
        ners = np.array(ners[0])
        mask = ners != 'O'
        lemmatize_text = lemmatize(text.lower())
        text_lemm_set = set(lemmatize_text.split())
        find_words = apply_lemm(['где'])
        path_words = apply_lemm(['как пройти', 'пройти', 'путь'])
        toilet = apply_lemm(['туалет','гардероб', 'камера хранения', 'камера', 'хранения'])
        if len(set(find_words) & text_lemm_set) > 0: # FIND CASE
            for i, cl in enumerate(ners):
                if 'ORG' in cl:
                    mask[i] = False
            search_queue = ['', [''], ' '.join(tokens[mask])]
            search_result = models['search'].find(search_queue) #TODO: specify search_result, return search_result
            # Хотите ли вы туда пройти?
        elif len(set(path_words) & text_lemm_set) > 0: # Хочу пройти к 
            state['return_to_id'] = 0
            state['return_message'] = 'where'
            result = {'text': 'В каком зале вы сейчас находитесь?'}
            return result
        elif len(set(path_words) & text_lemm_set) > 0:
            return {'text': 'Идите к лестнице, спуститесь на первый этаж. По лестнице у входа спуститесь ниже.'}

# %%
int(''.join(list(filter(str.isdigit, '16 зал'))))
# Out:
# 16

# %%
from deeppavlov import configs, build_model

# %%
ner_model = build_model(configs.ner.ner_ontonotes_bert_mult, download=False)
# Out:
# 2019-09-28 19:57:11.821 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 112: [loading vocabulary from /home/captain/.deeppavlov/models/ner_ontonotes_bert_mult/tag.dict]
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f0cf14481d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f0cf14481d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# ...

# %%
tokens, ners = ner_model(['Где в Пушкинском музее'])

# %%
mask  = np.array(ners[0]) != 'O'

# %%
np.array(tokens[0])[mask]
# Out:
# array([], dtype='<U10')

# %%
len(set(['где', 'когда']) & set(['где', 'кому']))
# Out:
# 1

# %%
'где-то очень далеко был заяц'.split()
# Out:
# ['где-то', 'очень', 'далеко', 'был', 'заяц']
